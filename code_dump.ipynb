# %%
import nltk
import string
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# nltk.download('punkt')
# nltk.download('wordnet') 
# nltk.download('omw-1.4')
# nltk.download("stopwords")

reviews = pd.read_parquet('data\\reviews_preprocessed.parquet')

# reviews.info()

# lemmatizer = WordNetLemmatizer()
# stopwords = stopwords.words('english')
# reviews["reviewText"] = reviews["reviewText"].astype('str')

# reviews["reviewTokens"] = reviews["reviewText"]
# reviews["reviewTokens"] = reviews["reviewTokens"].apply(lambda a: a.lower())
# reviews["reviewTokens"] = reviews["reviewTokens"].str.replace('[{}]'.format(string.punctuation), '')
# reviews["reviewTokens"] = reviews["reviewTokens"].str.replace('[{}]'.format(string.punctuation), '')
# reviews["reviewTokens"] = reviews["reviewTokens"].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
# reviews["reviewTokens"] = reviews["reviewTokens"].apply(lambda a: lemmatizer.lemmatize(a))
# reviews["reviewTokens"] = reviews["reviewTokens"].apply(word_tokenize)

# %%
# stopwords = nltk.download("stopwords")

# %%
nltk.download('omw-1.4')
lemmatizer = WordNetLemmatizer()
reviews["reviewTokens"] = reviews["reviewTokens"].apply(lambda a: lemmatizer.lemmatize(a))
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\sammi\AppData\Roaming\nltk_data...

# %%
from nltk.util import ngrams
reviews['reviewTokens'] = reviews["reviewTokens"].apply(lambda row: list(nltk.ngrams(row, 2)))

# %%
reviews
# Out:
#             reviewerID        asin       reviewerName helpful  \
# 0       A30TL5EWN6DFXT  120401325X          christina  [0, 0]
# 1        ASY55RVNIL0UD  120401325X           emily l.  [0, 0]
# 2       A2TMXE2AFO7ONB  120401325X              Erica  [0, 0]
# 3        AWJ0WZQYMYFQ4  120401325X                 JM  [4, 4]
# 4        ATX7CZYFXI1KW  120401325X   patrice m rogoza  [2, 3]
# ...                ...         ...                ...     ...
# 194434  A1YMNTFLNDYQ1F  B00LORXVUE    eyeused2loveher  [0, 0]
# 194435  A15TX8B2L8B20S  B00LORXVUE       Jon Davidson  [0, 0]
# 194436  A3JI7QRZO1QG8X  B00LORXVUE  Joyce M. Davidson  [0, 0]
# 194437  A1NHB2VC68YQNM  B00LORXVUE     Nurse Farrugia  [0, 0]
# 194438  A1AG6U022WHXBF  B00LORXVUE     Trisha Crocker  [0, 0]
#
#                                                reviewText  overall  \
# 0       They look good and stick good! I just don't li...      4.0
# 1       These stickers work like the review says they ...      5.0
# 2       These are awesome and make my phone look so st...      5.0
# 3       Item arrived in great time and was in perfect ...      4.0
# 4       awesome! stays on, and looks great. can be use...      5.0
# ...                                                   ...      ...
# 194434  Works great just like my original one. I reall...      5.0
# 194435  Great product. Great packaging. High quality a...      5.0
# 194436  This is a great cable, just as good as the mor...      5.0
# 194437  I really like it becasue it works well with my...      5.0
# 194438  product as described, I have wasted a lot of m...      5.0
#
#                                                   summary  unixReviewTime  \
# 0                                              Looks Good      1400630400
# 1                                   Really great product.      1389657600
# 2                                          LOVE LOVE LOVE      1403740800
# 3                                                   Cute!      1382313600
# 4               leopard home button sticker for iphone 4s      1359849600
# ...                                                   ...             ...
# 194434                           This works just perfect!      1405900800
# 194435           Great replacement cable. Apple certified      1405900800
# 194436                                       Real quality      1405900800
# 194437  I really like it becasue it works well with my...      1405814400
# 194438              I have wasted a lot of money on cords      1405900800
#
#          reviewTime                                       reviewTokens
# 0       05 21, 2014  [[look, good], [good, stick], [stick, good], [...
# 1       01 14, 2014  [[stickers, work], [work, like], [like, review...
# 2       06 26, 2014  [[awesome, make], [make, phone], [phone, look]...
# 3       10 21, 2013  [[item, arrived], [arrived, great], [great, ti...
# 4        02 3, 2013  [[awesome, stays], [stays, looks], [looks, gre...
# ...             ...                                                ...
# 194434  07 21, 2014  [[works, great], [great, like], [like, origina...
# 194435  07 21, 2014  [[great, product], [product, great], [great, p...
# 194436  07 21, 2014  [[great, cable], [cable, good], [good, expensi...
# 194437  07 20, 2014  [[really, like], [like, becasue], [becasue, wo...
# 194438  07 21, 2014  [[product, described], [described, wasted], [w...
#
# [194439 rows x 10 columns]
